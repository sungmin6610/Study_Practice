# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')

#1
print(df.info)

#2
print(df.columns)

#3
print(df.head(10))

#4
print(df['pclass'].unique()) #print(df['pclass'].value.counts()) 도수분포 

#5
print(df.iloc[2, 4])

#6
print(df.loc[:4, ['pclass', 'sex', 'age', 'alive']])

#7
print(df.loc[df['age'] >= 60, ['sex','age','alive']])

#8
print(df.loc[(df.age<10) & (df.sex == 'female'), ['age','alive']])

#9
print(df.loc[(df.alive=='yes') & (df.sex == 'male'), 'age'].mean())

#10
print[(df.alive == 'yes'), 'alive'].count() / df.alive.count() * 100

#11
print[(df.alive == 'yes' & df.age == df.age.min()),['sex','age']]

#12
print(df.loc[(df.pclass == 1)&(df.alive=='yes')].count())

#13
print(df.loc[(df.pclass == 1), 'pclass'].count() - df.loc[(df.pclass == 2), 'pclass'].count())

#14
tmp = df.loc[(df.pclass==3) & (df.alive == 'yes'),['sex','age']]
print(tmp)

#15
df2 = df.loc[:, ['pclass', 'sex', 'age', 'alive']].copy()
print(df2 = df.loc[:, ['pclass', 'sex', 'age', 'alive']].copy())

#16
df2['age_class'] = None
print(df2.loc[df2.age < 40,'age_class'] = 'Low')
print(df2.loc[df2.age >= 40,'age_class'] = 'High')
print(df2)

#17
print(df2.age + 10)

#18
df3=df2['age'] + 10
print(df3.mean())

#19
print(df2.loc[:, ~df2.columns.isin(['pclass'])])

#20
print(df2.to_csv('d:/data/titanic2.csv', index = False))
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
