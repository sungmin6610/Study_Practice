# %% [markdown]
# # 챕터 3 연습문제 풀이

# %%
#1
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(sales)
# Out:
# A    781
# B    650
# C    705
# D    406
# E    580
# F    450
# G    550
# H    640
# dtype: int64

# %%
#2
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(len(sales))
# Out:
# 8

# %%
#3
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(sales.iloc[1])
# Out:
# 650

# %%
#4
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(sales['F'])
# Out:
# 450

# %%
#5
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(sales.iloc[2:5])
# Out:
# C    705
# D    406
# E    580
# dtype: int64

# %%
#6
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(sales[['A','B','C']])
# Out:
# A    781
# B    650
# C    705
# dtype: int64

# %%
#7
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(sales[sales >= 600])
# Out:
# A    781
# B    650
# C    705
# H    640
# dtype: int64

# %%
#8
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
sales = pd.Series(data, index=teams)

print(sales[(sales<500)|(sales>700)])
# Out:
# A    781
# C    705
# D    406
# F    450
# dtype: int64

# %%
#9
import pandas as pd

data = ([781, 650, 705, 406, 580, 450, 550, 640])
teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 6
#       4 data = ([781, 650, 705, 406, 580, 450, 550, 640])
#       5 teams = (['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
# ----> 6 print(sales > ['B'])
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# ...
