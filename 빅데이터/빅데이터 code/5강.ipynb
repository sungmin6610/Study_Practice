# %%
import pandas as pd
import matplotlib.pyplot as plt

favorite = pd.Series(['WINTER', 'SUMMER', 'SPRING', 'SUMMER', 'SUMMER', 'FALL', 'FALL', 'SUMMER', 'SPRING', 'SPRING', 'SPRING'])
print(favorite)
print(favorite.value_counts())
print(favorite.value_counts()/favorite.size)

fd = favorite.value_counts()
print(type(fd))
print(fd['SUMMER'])
print(fd.iloc[2])

#파이썬에서 두 그래프 한번에 출력하는법: 
fig, axes = plt.subplots(2, 2, figsize=(15,10))
fd.plot.bar(xlabel='Season',
            ylabel='Frequency',
            rot=0,
            title='Favorite Season',
            ax=axes[0,0])

fd.plot.bar(xlabel='Frequency',
            ylabel='Season',
            rot=0,
            title='Favorite Season', ax=axes[1,1] )
plt.subplots_adjust(left=0.2)
fig.suptitle('Favorite Season Gragh')
plt.show()

fd.plot.pie(ylabel='',
            autopct='%1.2f%%',
            title='Favorite Season')
plt.subplots_adjust(wspace=0.3, hspace=0.3) 
fig.suptitle('Favorite Season Graph')
plt.show()
# Out:
# 0     WINTER
# 1     SUMMER
# 2     SPRING
# 3     SUMMER
# 4     SUMMER
# 5       FALL
# 6       FALL
# 7     SUMMER
# 8     SPRING
# 9     SPRING
# 10    SPRING
# dtype: object
# SUMMER    4
# SPRING    4
# FALL      2
# WINTER    1
# Name: count, dtype: int64
# SUMMER    0.363636
# SPRING    0.363636
# FALL      0.181818
# WINTER    0.090909
# Name: count, dtype: float64
# <class 'pandas.core.series.Series'>
# 4
# 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/cars.csv')
dist = df['dist']
print(dist)

dist.plot.hist()
plt.show()

dist.plot.hist(bins=6)
plt.show()

print(dist.value_counts(bins=6, sort=False))

dist.plot.hist(bins=6,
               title='Braking distance',
               xlabel='distance',
               ylabel='frequency',
               color='g')     
plt.show()

print(dist.describe())
dist.plot.box(title='Breaking distance')
plt.show()
# Out:
# 0       2
# 1      10
# 2       4
# 3      22
# 4      16
# 5      10
# 6      18
# 7      26
# 8      34
# 9      17
# 10     28
# 11     14
# 12     20
# 13     24
# 14     28
# 15     26
# 16     34
# 17     34
# 18     46
# 19     26
# 20     36
# 21     60
# 22     80
# 23     20
# 24     26
# 25     54
# 26     32
# 27     40
# 28     32
# 29     40
# 30     50
# 31     42
# 32     56
# 33     76
# 34     84
# 35     36
# 36     46
# 37     68
# 38     32
# 39     48
# 40     52
# 41     56
# 42     64
# 43     66
# 44     54
# 45     70
# 46     92
# 47     93
# 48    120
# 49     85
# Name: dist, dtype: int64
# (1.881, 21.667]      10
# (21.667, 41.333]     18
# (41.333, 61.0]       11
# (61.0, 80.667]        6
# (80.667, 100.333]     4
# (100.333, 120.0]      1
# Name: count, dtype: int64
# count     50.000000
# mean      42.980000
# std       25.769377
# min        2.000000
# 25%       26.000000
# 50%       36.000000
# 75%       56.000000
# max      120.000000
# Name: dist, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/iris.csv')

df.boxplot(column = 'Petal_Length', by = 'Species', grid = False)
plt.suptitle('')
plt.show()
print(df.describe())
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc('font', family='Malgun Gothic')
#plt.rc('axes', unicode_minus=False)

# 0~2π 범위 생성
np.linspace(0, 100, 100)
x = np.linspace(0, 2 * np.pi, 100)
plt.figure(figsize=(8, 5))

# 동일 x 범위에서 두 함수를 그리면 직접 비교 가능

plt.plot(x, np.sin(x), label="sin(x)", linewidth=2)
plt.plot(x, np.cos(x), label="cos(x)", linewidth=2)

plt.title("sin(x)와 cos(x) 비교 그래프")
plt.xlabel("x (라디안)")
plt.ylabel("함수 값")
plt.legend() # 그래프 구분을 위한 범례
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/iris.csv')

fig, axes = plt.subplots(nrows = 2, ncols =2 )

df['Petal_Length'].plot.hist(ax=axes[0, 0])
df['Petal_Length'].plot.box(ax=axes[0, 1])

fd = df['Species'].value_counts()
fd.plot.pie(ax = axes[1, 0])
fd.plot.barh(ax = axes[1, 1])

fig.suptitle('Multiple Graph Example', fontsize = 14)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False

hobby = pd.Series(['등산', '낚시', '골프', '수영', '등산', '등산',
                 '낚시', '수영', '등산', '낚시', '수영', '골프'])

print(hobby)

fd = hobby.value_counts()
print(fd)

fig, axes = plt.subplots(nrows=1, ncols=2)

fd.plot.bar(ax=axes[0])
fd.plot.pie(ax=axes[1])

fig.suptitle('선호 취미 분포', fontsize = 14)
plt.show()
# Out:
# 0     등산
# 1     낚시
# 2     골프
# 3     수영
# 4     등산
# 5     등산
# 6     낚시
# 7     수영
# 8     등산
# 9     낚시
# 10    수영
# 11    골프
# dtype: object
# 등산    4
# 낚시    3
# 수영    3
# 골프    2
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/BostonHousing.csv')
house_price = df['medv']
#print(house_price)

print(house_price.mean())
print(house_price.median())
print(house_price.quantile([0.25, 0.5, 0.75]))

quan = house_price.quantile([0.25, 0.5, 0.75])
bins = [house_price.min(), quan[0.25], quan[0.5], quan[0.75], house_price.max()]
labels = ['Q1', 'Q2', 'Q3', 'Q4']
grp = pd.cut(house_price, bins=bins, labels=labels)
avg = house_price.groupby(grp).mean()

avg.plot.bar()
plt.xlabel('Quartiles')
plt.ylabel('House Price')
plt.title('Average House Price by Quartiles')
plt.show()

house_price.plot.box()
plt.show()

house_price.plot.hist(bins=8)
plt.show()
# Out:
# 22.532806324110677
# 21.2
# 0.25    17.025
# 0.50    21.200
# 0.75    25.000
# Name: medv, dtype: float64
# C:\Users\user\AppData\Local\Temp\ipykernel_51160\1848423330.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg = house_price.groupby(grp).mean()
