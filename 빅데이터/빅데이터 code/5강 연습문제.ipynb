# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
#1
df = sns.load_dataset('tips')
day = df.day

#2
print(day.unique())

#3
fd = day.value_counts()

#4
fd/len(day)

#5
fd.plot.bar(xlabel = 'Day', ylabel = 'Frequency', rot = 0, title = "number", color = 'b', grid = True, figsize = (6, 4))
plt.subplots_adjust(bottom=0.2)
plt.show()

#6
fd.plot.barh(xlabel = 'Day', ylabel = 'Frequency', rot = 0, title = "number", color = 'r', grid = True, figsize = (6, 4))
plt.subplots_adjust(bottom=0.2)
plt.show()

#7
col = ['lightblue', 'lightgreen', 'lightpink', 'lightyellow']
lbl = ['thur', 'fri', 'sat', 'sun']
exp = [0, 0.10, 0, 0.10]
wedge = {'edgecolor':'b', 'linewidth':6, 'width': 0.8}
fd.plot.pie(ylabel='', title='number', autopct = '%.lf%%', colors=col, labels=lbl, figsize = (6, 6), counterclock = False, wedgeprops=wedge)
plt.show()

#8
smoker = df.smoker
fd1 = smoker.value_counts()
col = ['lightblue', 'lightred']
lbl = ['흡연자', '비흡연자']
fd1.plot.bar(xlabel = '흡연여부', ylabel = 'Frequency', rot = 0, title = "흡연별 손님수", color = 'b', grid = True, figsize = (6, 4))
plt.subplots_adjust(bottom=0.2)
plt.show()

#9
fd2 = df.time.value_counts()
print(fd2)
col = ['lightblue', 'lightred']
lbl = ['점심', '저녁']
fd2.plot.pie(ylabel = '', title = "식사 시간별 손님수", autopct = '%.1f%%', colors = 'col', figsize = (6, 6))

plt.subplots_adjust(bottom=0.2)
plt.show()

#10
amount = df['total_bill']

#11
amount.describe()

#12
amount.quantile([0.25, 0.5, 0.75])

#13
amount.plot.hist(bins=6)

#14
plt.show()

#15
amount.value_counts(bins=6, sort=False)

#16
amount.plot.box(title = '식사 금액')

#17
df.boxplot(columns)
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 50
#      48 col = ['lightblue', 'lightred']
#      49 lbl = ['점심', '저녁']
# ---> 50 fd2.plot.pie(ylabel = '', title = "식사 시간별 손님수", autopct = '%.1f%%', colors = 'col', figsize = (6, 6))
#      52 plt.subplots_adjust(bottom=0.2)
#      53 plt.show()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:1658, in PlotAccessor.pie(self, **kwargs)
#    1652 if (
#    1653     isinstance(self._parent, ABCDataFrame)
#    1654     and kwargs.get("y", None) is None
#    1655     and not kwargs.get("subplots", False)
#    1656 ):
#    1657     raise ValueError("pie requires either y column or 'subplots=True'")
# ...
