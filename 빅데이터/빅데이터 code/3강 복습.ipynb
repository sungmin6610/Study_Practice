# %%
import pandas as pd
import numpy as np

temp = pd.Series([-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 25.9, 25.3, 21.0, 14.0, 9.6, -1.4])
temp.index = ['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']

# print (temp)
# print (temp.index)

# print(temp.size)
# print(len(temp))
# print(temp.shape)
# print(temp.dtype)
# print(temp.shape[0]) # 행의 개수, 1을 넣으면 열의 개수

# print(temp.iloc[2]) 
# print(temp.loc['3월']) 
# print(temp.iloc[[3,5,7]]) 
# print(temp.loc[['4월', '5월', '6월']]) 
# print(temp.iloc[5:8]) 
# print(temp.loc['6월':'9월']) 
# print(temp.iloc[:4])  
# print(temp.iloc[9:]) 
# print(temp.iloc[:])

# print(temp.loc[temp>=15])
# print(temp.loc[temp>=15].index)
# print(temp.loc[(temp>=15) & (temp<25)])
# print(temp.loc[(temp<5)|(temp>=25)])
# march = temp.loc['3월']
# print(temp.loc[temp < march])
# print(temp.where(temp >= 15))
# print(temp.where(temp >= 15).dropna())
# temp.reset_index(drop=True, inplace=True)
# print(temp)

# print(temp + 1)
# print(2*temp+0.1)
# print(temp + temp)
# print(temp.loc[temp>=15]+1)

# print(temp.sum())
# print(temp.median())
# print(temp.mean())
# print(temp.max())
# print(temp.min())
# print(temp.std())
# print(temp.var())
# print(temp.abs())
# print(temp.describe())
# print(temp.value_counts())
# Out:
# 1월      0.2
# 2월      0.9
# 3월      8.7
# 4월     14.8
# 5월     19.0
# 6월     23.4
# 7월     26.9
# 8월     26.3
# 9월     22.0
# 10월    15.0
# 11월    10.6
# 12월    -0.4
# dtype: float64

# %%
import pandas as pd

salary = pd.Series([20, 15, 18, 30])
score = pd.Series([75, 80, 90, 60], index=['KOR', 'ENG', 'MATH', 'SOC'])

# print(salary)
# print(score)

# score.iloc[0] =85
# print(score)
# score.loc['SOC'] = 65
# print(score)
# score.loc[['ENG','MATH']] = [70, 80]
# print(score)

# new = pd.Series({'MUS': 95})
# score = pd.concat([score, new])
# print(score)

# new1 = pd.Series({'ART': 100})
# score = pd.concat([score[:2], new1, score[2:]])
# print(score)

# new0 = pd.Series({'SCI': 88})
# score = pd.concat([new0, score[:]])
# print(score)

# next_idx = salary.size
# salary.iloc[4] = 33
# salary.iloc[next_idx] = 33
# salary.loc[100] = 33
# print(salary)
# salary1=salary.reset_index(drop=True, inplace = True) # 인덱스 초기화
# print(salary1)

# score.drop('PHY')
# print(score)
# score.drop('PHY',inplace=True) 
# print(score) 

# salary = salary.drop(1) 
# print(salary)

# salary = salary.drop(2, inplace=True) 
# print(salary)

score1 = score
score1.loc['KOR'] = 95
print(score1)
print(score)

score3 = score1.copy()
score3.loc['KOR'] = 70
print(score3)
print(score1)
# Out:
# KOR     95
# ENG     80
# MATH    90
# SOC     60
# dtype: int64
# KOR     95
# ENG     80
# MATH    90
# SOC     60
# dtype: int64
# KOR     70
# ENG     80
# MATH    90
# SOC     60
# dtype: int64
# KOR     95
# ENG     80
# MATH    90
# SOC     60
# dtype: int64
